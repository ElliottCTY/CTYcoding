# %%
players=input("how many players? >> ")

# %%
if players=="1":
    gb=[["-","-","-"], 
        ["-","-","-"], 
        ["-","-","-"]]

    for i in gb:
        print(i)
    print("---------------")

    choice1=0
    choice2=0
    a=0
    j=0
    while j<9:
        while a<1:
            choice=input("X or O >> ")
            if choice=="O":
                a+=1
                first="O"
                second="X"
                choice1+=1
            elif choice=="X":
                a+=1
                first="X"
                second="O"
                choice1+=1
            else:
                print("your input is invalid")

        k=True
        while k==True:
            try: 
                z=int(input("please enter a row"))
                y=int(input("enter a coloum"))
                k=False

            except:
                print("your input is invalid")

        if gb[z][y]=="-":

            if choice1>choice2 and j!=8:
                gb[z][y]=first
                j+=1
                choice2+=1
                for i in gb:
                    print(i)
                print("---------------")

                if first==gb[0][0]== gb[0][1]== gb[0][2]!="-" or first==gb[1][0]== gb[1][1]== gb[1][2]!="-" or first==gb[2][0]== gb[2][1]== gb[2][2]!="-" or first==gb[0][0]== gb[1][0]== gb[2][0]!="-" or first==gb[0][1]== gb[1][1]== gb[2][1]!="-" or first==gb[0][2]== gb[1][2]== gb[2][2]!="-" or first==gb[0][0]== gb[1][1]== gb[2][2]!="-" or first==gb[0][2]== gb[1][1]== gb[2][0]!="-":
                    print(first,"wins")
                    break
            elif choice1==choice2 and j!=8:
                gb[z][y]=second
                j+=1
                choice1+=1
                for i in gb:
                    print(i)
                print("---------------")
                if second==gb[0][0]== gb[0][1]== gb[0][2]!="-" or second==gb[1][0]== gb[1][1]== gb[1][2]!="-" or second==gb[2][0]== gb[2][1]== gb[2][2]!="-" or second==gb[0][0]== gb[1][0]== gb[2][0]!="-" or second==gb[0][1]== gb[1][1]== gb[2][1]!="-" or second==gb[0][2]== gb[1][2]== gb[2][2]!="-" or second==gb[0][0]== gb[1][1]== gb[2][2]!="-" or second==gb[0][2]== gb[1][1]== gb[2][0]!="-":
                    print(second,"wins")
                    break
            elif j==8:
                print("tie")
                break
            else:
                print("this spot is already filled")
elif players=="2":
    print("place holder")
    
else:
    print("Too many players")

# %%
gb=[["-","-","-"], 
    ["-","-","-"], 
    ["-","-","-"]]

for i in gb:
    print(i)
print("---------------")
import random
rand1=random.randint(0,2)
rand2=random.randint(0,2)
choice1=0
choice2=0
b=0
a=0
j=0
ai=0
k=True
while j<9:
    while a<1:
        choice=input("X or O >> ")
        if choice=="O":
            a+=1
            first="O"
            second="X"
            choice1+=1
        elif choice=="X":
            a+=1
            first="X"
            second="O"
            choice1+=1
        else:
            print("your input is invalid")
    while b<1:
        start=input("ai going first or second >> ")
        if start=="first":
            b+=1
            ai+=1
        elif start=="second":
            b+=1
            ai+=2
        else:
            print("your input is invalid")
    
        if ai==1:
            print("ai first")
        
            if choice1>choice2 and j!=8:
                if gb[rand1][rand2]=="-":
                    gb[rand1][rand2]=first
                    j+=1
                    choice2+=1
                    for i in gb:
                        print(i)
                    print("---------------")

                    if first==gb[0][0]== gb[0][1]== gb[0][2]!="-" or first==gb[1][0]== gb[1][1]== gb[1][2]!="-" or first==gb[2][0]== gb[2][1]== gb[2][2]!="-" or first==gb[0][0]== gb[1][0]== gb[2][0]!="-" or first==gb[0][1]== gb[1][1]== gb[2][1]!="-" or first==gb[0][2]== gb[1][2]== gb[2][2]!="-" or first==gb[0][0]== gb[1][1]== gb[2][2]!="-" or first==gb[0][2]== gb[1][1]== gb[2][0]!="-":
                        print(first,"wins")
                        break
            elif choice1==choice2 and j!=8:
                while k==True:
                    try: 
                        z=int(input("please enter a row"))
                        y=int(input("enter a coloum"))
                        k=False
                    except:
                        print("your input is invalid")
                    if gb[z][y]=="-":
                        gb[z][y]=second
                        j+=1
                        choice1+=1
                        for i in gb:
                            print(i)
                        print("---------------")
                        if second==gb[0][0]== gb[0][1]== gb[0][2]!="-" or second==gb[1][0]== gb[1][1]== gb[1][2]!="-" or second==gb[2][0]== gb[2][1]== gb[2][2]!="-" or second==gb[0][0]== gb[1][0]== gb[2][0]!="-" or second==gb[0][1]== gb[1][1]== gb[2][1]!="-" or second==gb[0][2]== gb[1][2]== gb[2][2]!="-" or second==gb[0][0]== gb[1][1]== gb[2][2]!="-" or second==gb[0][2]== gb[1][1]== gb[2][0]!="-":
                            print(second,"wins")
                            break
            elif j==8:
                print("tie")
                break
            else:
                print("this spot is already filled")
        elif ai==2:
            print("ai is second")
            if choice1>choice2 and j!=8:
                k=True
                while k==True:
                    try: 
                        z=int(input("please enter a row"))
                        y=int(input("enter a coloum"))
                        k=False
                    except:
                        print("your input is invalid")
                gb[z][y]=second
                j+=1
                choice2+=1
                for i in gb:
                    print(i)
                print("---------------")

                if first==gb[0][0]== gb[0][1]== gb[0][2]!="-" or first==gb[1][0]== gb[1][1]== gb[1][2]!="-" or first==gb[2][0]== gb[2][1]== gb[2][2]!="-" or first==gb[0][0]== gb[1][0]== gb[2][0]!="-" or first==gb[0][1]== gb[1][1]== gb[2][1]!="-" or first==gb[0][2]== gb[1][2]== gb[2][2]!="-" or first==gb[0][0]== gb[1][1]== gb[2][2]!="-" or first==gb[0][2]== gb[1][1]== gb[2][0]!="-":
                    print(first,"wins")
                    break
            elif choice1==choice2 and j!=8:
                if gb[rand1][rand2]=="-":
                    gb[rand1][rand2]=first
                    j+=1
                    choice1+=1
                    for i in gb:
                        print(i)
                    print("---------------")
                    if second==gb[0][0]== gb[0][1]== gb[0][2]!="-" or second==gb[1][0]== gb[1][1]== gb[1][2]!="-" or second==gb[2][0]== gb[2][1]== gb[2][2]!="-" or second==gb[0][0]== gb[1][0]== gb[2][0]!="-" or second==gb[0][1]== gb[1][1]== gb[2][1]!="-" or second==gb[0][2]== gb[1][2]== gb[2][2]!="-" or second==gb[0][0]== gb[1][1]== gb[2][2]!="-" or second==gb[0][2]== gb[1][1]== gb[2][0]!="-":
                        print(second,"wins")
                        break
            break
# Out:
# ['-', '-', '-']
# ['-', '-', '-']
# ['-', '-', '-']
# ---------------
# ai first
# ['-', '-', '-']
# ['-', '-', '-']
# ['-', 'O', '-']
# ---------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 114
#     112             print(second,"wins")
#     113             break
# --> 114 break
#
# KeyboardInterrupt:
